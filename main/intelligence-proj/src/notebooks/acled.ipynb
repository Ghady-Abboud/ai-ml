# %%
import os

def load_data(file_path):
    import pandas as pd
    from src.data.preprocess import preprocess_acled_data

    data = pd.read_csv(file_path)
    cleaned_data = preprocess_acled_data(data)
    return cleaned_data

DATA_PATH = os.getcwd() + "/data/raw/irn_isr_acled.csv"
df_acled = load_data(DATA_PATH)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 12
#       9     return cleaned_data
#      11 DATA_PATH = os.getcwd() + "/data/raw/irn_isr_acled.csv"
# ---> 12 df_acled = load_data(DATA_PATH)
#
# Cell In[1], line 4, in load_data(file_path)
#       3 def load_data(file_path):
# ----> 4     import pandas as pd
#       5     from src.data.preprocess import preprocess_acled_data
#       7     data = pd.read_csv(file_path)
#
# ModuleNotFoundError: No module named 'pandas'
