# %%
import numpy as np

# %%
class RidgeRegression:
  def __init__(self, data, learning_rate = 0.01, alpha = 0.1):
    self.data = data
    self.learning_rate = learning_rate
    self.alpha = alpha
  
  def fit(self, X, y):
    wList = []
    # Get Gram Matrix
    xTranspose = X.T
    A = xTranspose @ X
    # Get Identity Matrix
    I = np.identity(A.shape[0])
    c = xTranspose @ y
